# %% [markdown]
# <a href="https://colab.research.google.com/github/delicate99/Python_ML/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas
from pandas import DataFrame
import matplotlib.pyplot as plt

# %%
from google.colab import files
myfile = files.upload()
# Out:
#      <input type="file" id="files-33addb53-9c3d-4467-8a1c-eca613e9dd72" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-33addb53-9c3d-4467-8a1c-eca613e9dd72">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cost_revenue_clean1.csv to cost_revenue_clean1.csv

# %%
myfile
# Out:
# {'cost_revenue_clean.csv': b'production_budget_usd,world_wide_usd\r\n"1,000,000.00",26.00\r\n"10,000.00",401.00\r\n"400,000.00",423.00\r\n"750,000.00",450.00\r\n"10,000.00",527.00\r\n"1,800,000.00",673.00\r\n"1,000,000.00",703.00\r\n"6,600,000.00",828.00\r\n"1,000,000.00",884.00\r\n"7,000.00",900.00\r\n"2,000,000.00",926.00\r\n"1,000,000.00","1,036.00"\r\n"700,000.00","1,160.00"\r\n"200,000.00","1,217.00"\r\n"9,000,000.00","1,242.00"\r\n"12,000.00","1,336.00"\r\n"5,000.00","1,338.00"\r\n"100,000.00","1,358.00"\r\n"1,400,000.00","1,632.00"\r\n"300,000.00","1,711.00"\r\n"500,000.00","1,778.00"\r\n"500,000.00","1,822.00"\r\n"10,000.00","1,987.00"\r\n"1,500,000.00","2,105.00"\r\n"5,000,000.00","2,199.00"\r\n"9,000,000.00","2,243.00"\r\n"2,000,000.00","2,436.00"\r\n"175,000.00","2,602.00"\r\n"1,100,000.00","2,636.00"\r\n"6,500,000.00","3,149.00"\r\n"3,380,000.00","3,220.00"\r\n"250,000.00","3,234.00"\r\n"850,000.00","3,256.00"\r\n"1,600,000.00","3,264.00"\r\n"600,000.00","3,301.00"\r\n"2,
# ...

# %%
data = pandas.read_csv('cost_revenue_clean1.csv')

# %%
data
# Out:
#       production_budget_usd  Worldwide_gross_usd
# 0                 1000000.0         2.600000e+01
# 1                   10000.0         4.010000e+02
# 2                  400000.0         4.230000e+02
# 3                  750000.0         4.500000e+02
# 4                   10000.0         5.270000e+02
# ...                     ...                  ...
# 5029            225000000.0         1.519480e+09
# 5030            215000000.0         1.671641e+09
# 5031            306000000.0         2.058662e+09
# 5032            200000000.0         2.207616e+09
# 5033            425000000.0         2.783919e+09
#
# [5034 rows x 2 columns]

# %%
data.describe()
# Out:
#        production_budget_usd  Worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %% [markdown]
# X = DataFrame(numpy.float(data), columns=['production_budget_usd'])
# y = DataFrame(data, columns=['world_wide_usd'])
#
# type(X)

# %%
y = DataFrame(data, columns=['Worldwide_gross_usd'])
print(y)
# Out:
#       Worldwide_gross_usd
# 0            2.600000e+01
# 1            4.010000e+02
# 2            4.230000e+02
# 3            4.500000e+02
# 4            5.270000e+02
# ...                   ...
# 5029         1.519480e+09
# 5030         1.671641e+09
# 5031         2.058662e+09
# 5032         2.207616e+09
# 5033         2.783919e+09
#
# [5034 rows x 1 columns]

# %%
X = DataFrame(data, columns=["production_budget_usd"])
X
Y = DataFrame(data, columns=["Worldwide_gross_usd"])
Y
plt.scatter(X,Y)

# %%
plt.figure(figsize=(10,6))
plt.scatter(X,Y, alpha = 0.3)
plt.title('Film Cost vs Global Revenue')
plt.xlabel('Production Budget $')
plt.ylabel('Worldwide Gross $')
plt.xlim(0, 450000000)
plt.ylim(0, 3000000000)
plt.show()
